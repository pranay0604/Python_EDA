# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# '/Users/pranay/Naresh IT/Python/EDA'

# %%
bank = pd.read_csv('/Users/pranay/Naresh IT/Data Files/bank.csv')

# %%
bank.head()
# Out:
#   age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0  30;"unemployed";"married";"primary";"no";1787;...
# 1  33;"services";"married";"secondary";"no";4789;...
# 2  35;"management";"single";"tertiary";"no";1350;...
# 3  30;"management";"married";"tertiary";"no";1476...
# 4  59;"blue-collar";"married";"secondary";"no";0;...

# %%
visa = pd.read_csv('/Users/pranay/Naresh IT/Data Files/Visadataset.csv')

# %%
visa.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
bank = pd.read_csv('/Users/pranay/Naresh IT/Data Files/bank.csv',sep=';')
bank.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
bank
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
visa.shape
# Out:
# (25480, 12)

# %%
visa.size
# Out:
# 305760

# %%
visa.head(5)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa.tail(5)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
visa.info
# Out:
# <bound method DataFrame.info of          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa.isnull
# Out:
# <bound method DataFrame.isnull of          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
visa.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(visa)
# Out:
# pandas.core.frame.DataFrame

# %%
type(visa.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
cols = visa.columns
cols
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
cols.index('continent')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 cols.index('continent')
#
# AttributeError: 'Index' object has no attribute 'index'

# %%
l = ['a','b','c']
l.index('b')
# Out:
# 1

# %%
cols = visa.columns.to_list()
cols.index('continent')
# Out:
# 1

# %% [markdown]
# **loc and iloc**

# %%
# visa.iloc[<rows>,<columns>]

# l[start:stop:step]

# visa.iloc[start:stop:step , start:stop:step]

# %%
visa.iloc[100:105,3:7]
# columns index 3 to 6
# rows 100 to 104
# Out:
#     has_job_experience requires_job_training  no_of_employees  yr_of_estab
# 100                  Y                     N             2227         2007
# 101                  Y                     N              334         2007
# 102                  Y                     N              224         2008
# 103                  Y                     N              367         1982
# 104                  Y                     N              306         2003

# %%
visa.iloc[100]
# series data
# Out:
# case_id                    EZYV101
# continent                     Asia
# education_of_employee     Master's
# has_job_experience               Y
# requires_job_training            N
# no_of_employees               2227
# yr_of_estab                   2007
# region_of_employment     Northeast
# prevailing_wage           28243.79
# unit_of_wage                  Year
# full_time_position               Y
# case_status              Certified
# Name: 100, dtype: object

# %%
visa.iloc[[100]]
# dataframe data
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified

# %%
visa.iloc[[100,200]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified

# %% [markdown]
# - **Series and Dataframe** look like both are same but not same
#
# - Series is a **1D data**
#
# - Series is like a **key-value pair**
#
# - Dataframe is a **2D data**
#
# - If you want to select **multiple values** always **provide in a list**

# %%
visa.iloc[100].keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa.iloc[100].values
# Out:
# array(['EZYV101', 'Asia', "Master's", 'Y', 'N', 2227, 2007, 'Northeast',
#        28243.79, 'Year', 'Y', 'Certified'], dtype=object)

# %%
visa.iloc[100].keys()
visa.iloc[100].index
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
pd.DataFrame(visa.iloc[100])
# Out:
#                              100
# case_id                  EZYV101
# continent                   Asia
# education_of_employee   Master's
# has_job_experience             Y
# requires_job_training          N
# no_of_employees             2227
# yr_of_estab                 2007
# region_of_employment   Northeast
# prevailing_wage         28243.79
# unit_of_wage                Year
# full_time_position             Y
# case_status            Certified

# %%
dict(visa.iloc[100])
# Out:
# {'case_id': 'EZYV101',
#  'continent': 'Asia',
#  'education_of_employee': "Master's",
#  'has_job_experience': 'Y',
#  'requires_job_training': 'N',
#  'no_of_employees': 2227,
#  'yr_of_estab': 2007,
#  'region_of_employment': 'Northeast',
#  'prevailing_wage': 28243.79,
#  'unit_of_wage': 'Year',
#  'full_time_position': 'Y',
#  'case_status': 'Certified'}

# %%
pd.DataFrame(visa.iloc[[100,200]])
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified

# %%
visa.iloc[[100,200,300],[3,6,9]]
# Out:
#     has_job_experience  yr_of_estab unit_of_wage
# 100                  Y         2007         Year
# 200                  Y         1979         Year
# 300                  Y         2012         Year

# %%
visa.iloc[[100,200,300],]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa.iloc[[100,200,300],:]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa.iloc[:,[3,6,9]]
# Out:
#       has_job_experience  yr_of_estab unit_of_wage
# 0                      N         2007         Hour
# 1                      Y         2002         Year
# 2                      N         2008         Year
# 3                      N         1897         Year
# 4                      Y         2005         Year
# ...                  ...          ...          ...
# 25475                  Y         2008         Year
# 25476                  Y         2006         Year
# 25477                  Y         1910         Year
# 25478                  Y         1887         Year
# 25479                  Y         1960         Year
#
# [25480 rows x 3 columns]

# %%
visa.iloc[:,:]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa.iloc[:,3]
# Out:
# 0        N
# 1        Y
# 2        N
# 3        N
# 4        Y
#         ..
# 25475    Y
# 25476    Y
# 25477    Y
# 25478    Y
# 25479    Y
# Name: has_job_experience, Length: 25480, dtype: object

# %%
visa.iloc[:,[3]]
# Out:
#       has_job_experience
# 0                      N
# 1                      Y
# 2                      N
# 3                      N
# 4                      Y
# ...                  ...
# 25475                  Y
# 25476                  Y
# 25477                  Y
# 25478                  Y
# 25479                  Y
#
# [25480 rows x 1 columns]

# %%
visa[:,1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (slice(None, None, None), 1)
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 visa[:,1]
#
# ...

# %%
visa[:,[1]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), [1])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 visa[:,[1]]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
# ...

# %%
visa[100]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 100
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 visa[100]
#
# ...

# %%
visa.values
# Out:
# array([['EZYV01', 'Asia', 'High School', ..., 'Hour', 'Y', 'Denied'],
#        ['EZYV02', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV03', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Denied'],
#        ...,
#        ['EZYV25478', 'Asia', "Master's", ..., 'Year', 'N', 'Certified'],
#        ['EZYV25479', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV25480', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Certified']],
#       dtype=object)

# %%
visa.values[100]
# Out:
# array(['EZYV101', 'Asia', "Master's", 'Y', 'N', 2227, 2007, 'Northeast',
#        28243.79, 'Year', 'Y', 'Certified'], dtype=object)

# %% [markdown]
# **DataFrames to Values**

# %%
visa.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa.loc[[100,200,300],['continent','unit_of_wage']]
# Out:
#     continent unit_of_wage
# 100      Asia         Year
# 200      Asia         Year
# 300      Asia         Year

# %%
visa.loc[:,['continent','unit_of_wage']]
# Out:
#       continent unit_of_wage
# 0          Asia         Hour
# 1          Asia         Year
# 2          Asia         Year
# 3          Asia         Year
# 4        Africa         Year
# ...         ...          ...
# 25475      Asia         Year
# 25476      Asia         Year
# 25477      Asia         Year
# 25478      Asia         Year
# 25479      Asia         Year
#
# [25480 rows x 2 columns]

# %%
visa.loc[:,:]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa.loc[[100],['continent','unit_of_wage']]
# Out:
#     continent unit_of_wage
# 100      Asia         Year

# %%
visa.loc[[1,2,3],['continent','unit_of_wage','education_of_employee']]
# Out:
#   continent unit_of_wage education_of_employee
# 1      Asia         Year              Master's
# 2      Asia         Year            Bachelor's
# 3      Asia         Year            Bachelor's

# %%
visa.loc[100]
# Out:
# case_id                    EZYV101
# continent                     Asia
# education_of_employee     Master's
# has_job_experience               Y
# requires_job_training            N
# no_of_employees               2227
# yr_of_estab                   2007
# region_of_employment     Northeast
# prevailing_wage           28243.79
# unit_of_wage                  Year
# full_time_position               Y
# case_status              Certified
# Name: 100, dtype: object

# %%
visa.loc[[100]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified

# %%
visa.loc[[100,200],'continent':'yr_of_estab']
# Out:
#     continent education_of_employee has_job_experience requires_job_training  \
# 100      Asia              Master's                  Y                     N
# 200      Asia             Doctorate                  Y                     N
#
#      no_of_employees  yr_of_estab
# 100             2227         2007
# 200             3282         1979

# %%
visa.loc[101:105,'continent':'yr_of_estab']
# Out:
#          continent education_of_employee has_job_experience  \
# 101           Asia              Master's                  Y
# 102           Asia            Bachelor's                  Y
# 103           Asia             Doctorate                  Y
# 104           Asia              Master's                  Y
# 105  North America             Doctorate                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab
# 101                     N              334         2007
# 102                     N              224         2008
# 103                     N              367         1982
# 104                     N              306         2003
# 105                     N             2317         1995

# %%
visa.loc[101:105,:]
# Out:
#      case_id      continent education_of_employee has_job_experience  \
# 101  EZYV102           Asia              Master's                  Y
# 102  EZYV103           Asia            Bachelor's                  Y
# 103  EZYV104           Asia             Doctorate                  Y
# 104  EZYV105           Asia              Master's                  Y
# 105  EZYV106  North America             Doctorate                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 101                     N              334         2007              Midwest
# 102                     N              224         2008              Midwest
# 103                     N              367         1982                 West
# 104                     N              306         2003            Northeast
# 105                     N             2317         1995               Island
#
#      prevailing_wage unit_of_wage full_time_position case_status
# ...

# %%
visa.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# **Dtypes**

# %%
visa.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %% [markdown]
# - object indicates Categorical column
#
# - dtypes gives series operations

# %%
visa.dtypes.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa.dtypes.values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O')], dtype=object)

# %%
visa.dtypes.index
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
cols = visa.dtypes.index
cols
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
values = visa.dtypes.values
values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O')], dtype=object)

# %%
cols = visa.dtypes.keys()
cols
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
pd.DataFrame(zip(cols,values),columns=['Columns','Data Type'])
# Out:
#                   Columns Data Type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %%
cols = visa.dtypes.index
values = visa.dtypes.values
pd.DataFrame(zip(cols,values),columns=['Columns','Data Type'])
# Out:
#                   Columns Data Type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %%
visa
dtypes = visa.dtypes
pd.DataFrame(dtypes)
df = pd.DataFrame(dtypes).reset_index()
df.columns
df.columns = ['Column Name','Data Type']
df
# Out:
#               Column Name Data Type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %%
df = pd.DataFrame(visa.dtypes).reset_index()
df.columns = ['Column Name','Data Types']
df
# Out:
#               Column Name Data Types
# 0                 case_id     object
# 1               continent     object
# 2   education_of_employee     object
# 3      has_job_experience     object
# 4   requires_job_training     object
# 5         no_of_employees      int64
# 6             yr_of_estab      int64
# 7    region_of_employment     object
# 8         prevailing_wage    float64
# 9            unit_of_wage     object
# 10     full_time_position     object
# 11            case_status     object

# %%
visa.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
cols = visa.dtypes.keys().tolist()
data_types = visa.dtypes.values.tolist()
cat = [i for i,j in zip(cols,data_types) if j=='object']
num = [i for i,j in zip(cols,data_types) if j!='object']
# for i,j in zip(cols,data_types):
#     if j=='object':
#         print(i)
print(cat)
print()
print(num)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
#
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %% [markdown]
# **select dtypes**

# %%
cat = visa.select_dtypes(include='object').columns
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num = visa.select_dtypes(exclude='object').columns
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
visa['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa[['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa.continent
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa.iloc[:,1]
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa.iloc[:,[1]]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa.loc[:,'continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa.loc[:,['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa['continent','case_status'] # wrong
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('continent', 'case_status')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[190], line 1
# ...

# %%
visa[['continent','case_status']] # correct
# Out:
#       continent case_status
# 0          Asia      Denied
# 1          Asia   Certified
# 2          Asia      Denied
# 3          Asia      Denied
# 4        Africa   Certified
# ...         ...         ...
# 25475      Asia   Certified
# 25476      Asia   Certified
# 25477      Asia   Certified
# 25478      Asia   Certified
# 25479      Asia   Certified
#
# [25480 rows x 2 columns]

# %% [markdown]
# **continent column**

# %%
visa['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %% [markdown]
# **unique**

# %%
visa['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %% [markdown]
# **nunique**

# %%
visa['continent'].nunique()
# Out:
# 6

# %% [markdown]
# **raw data**

# %%
visa['continent'].values
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'], dtype=object)

# %%
visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa
visa['continent']
visa['continent'] == 'Asia'
con = visa['continent'] == 'Asia'
visa[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
len(visa[con])
# Out:
# 16861

# %%
# con = visa['continent'] == 'Asia'
# len(visa[con])

# con = visa['continent'] == i

labels = visa['continent'].unique()
count = []
for i in labels:
    con = visa['continent'] == i
    count.append(len(visa[con]))
print(labels)
print(count)
# Out:
# ['Asia' 'Africa' 'North America' 'Europe' 'South America' 'Oceania']
# [16861, 551, 3292, 3732, 852, 192]

# %%
# cont = visa['continent'].unique()
# for i in cont:
#     con = visa['continent']== i
#     count = len(visa[con])
#     print(i,'=',count)

# %%
continent = pd.DataFrame(zip(labels,count), columns=['Continent','No of Applicants'])
continent
# Out:
#        Continent  No of Applicants
# 0           Asia             16861
# 1         Africa               551
# 2  North America              3292
# 3         Europe              3732
# 4  South America               852
# 5        Oceania               192

# %% [markdown]
# **value counts**

# %%
visa['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
keys = visa['continent'].value_counts().keys()
values = visa['continent'].value_counts().values
conti = pd.DataFrame(zip(keys,values),columns=['Continent','No of Applicants'])
conti
# Out:
#        Continent  No of Applicants
# 0           Asia             16861
# 1         Europe              3732
# 2  North America              3292
# 3  South America               852
# 4         Africa               551
# 5        Oceania               192

# %% [markdown]
# **group by**
#
# - Divide the continent into groups
#
# - there are 6 continents so 6 groups
#
# - then calculate each size

# %%
visa.groupby('continent').size()
# Out:
# continent
# Africa             551
# Asia             16861
# Europe            3732
# North America     3292
# Oceania            192
# South America      852
# dtype: int64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa = pd.read_csv('/Users/pranay/Naresh IT/Data Files/Visadataset.csv')

# %%
visa.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
cat = visa.select_dtypes(include='object').columns
num = visa.select_dtypes(exclude='object').columns

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# - Task 1 : Education of employee using frequency table using conditions
#
# - Task 2 : Education of employee using frequency table using value counts
#
# - Task 3 : Education of employee using frequency table using groupby
#
# - Task 4 : Create a new directory called frequency table and save the freq table of Educaton of employee value counts tasks

# %%
labels = visa['continent'].unique()
count = []
for i in labels:
    con = visa['continent'] == i
    count.append(len(visa[con]))
print(labels)
print(count)
# Out:
# ['Asia' 'Africa' 'North America' 'Europe' 'South America' 'Oceania']
# [16861, 551, 3292, 3732, 852, 192]

# %%
keys = visa['continent'].value_counts().keys()
values = visa['continent'].value_counts().values
conti = pd.DataFrame(zip(keys,values),columns=['Continent','No of Applicants'])
conti
# Out:
#        Continent  No of Applicants
# 0           Asia             16861
# 1         Europe              3732
# 2  North America              3292
# 3  South America               852
# 4         Africa               551
# 5        Oceania               192

# %%
visa.groupby('continent').size()
# Out:
# continent
# Africa             551
# Asia             16861
# Europe            3732
# North America     3292
# Oceania            192
# South America      852
# dtype: int64

# %%
keys = visa['education_of_employee'].value_counts().keys()
values = visa['education_of_employee'].value_counts().values
d = pd.DataFrame(zip(keys,values),columns=['Lables','No of Applicants'])
d.to_csv('education_of_employee.csv', index=False)

# %%
import os

os.makedirs('frequency_table',exist_ok=True)
# d.to_csv(<>,index=False)

# %%
os.getcwd()
# Out:
# '/Users/pranay/Naresh IT/Python/EDA'

# %%
path = r'/Users/pranay/Naresh IT/Python/EDA/frequency_table/education_of_employee.csv'
os.makedirs('frequency_table',exist_ok=True)

# %%
cwd = os.getcwd()
cwd
# Out:
# '/Users/pranay/Naresh IT/Python/EDA'

# %%
new_folder = os.makedirs('freq_table',exist_ok=True)

# %%
os.path.join(cwd,new_folder)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 os.path.join(cwd,new_folder)
#
# File <frozen posixpath>:90, in join(a, *p)
#
# File <frozen genericpath>:164, in _check_arg_types(funcname, *args)
#
# TypeError: join() argument must be str, bytes, or os.PathLike object, not 'NoneType'

# %%
cwd = os.getcwd()
cwd
folder_name = 'freq_table'
new_folder = os.makedirs(folder_name,exist_ok=True)
new_dir = os.path.join(cwd,folder_name)
new_dir
# Out:
# '/Users/pranay/Naresh IT/Python/EDA/freq_table'

# %%
col_name = 'education_of_employee'
file_path = os.path.join(new_dir,f"{col_name}.csv")
file_path
# Out:
# '/Users/pranay/Naresh IT/Python/EDA/freq_table/education_of_employee.csv'

# %%
for i in cat:
    cwd = os.getcwd()
    folder_name = 'freq_table_1'
    new_folder = os.makedirs(folder_name,exist_ok=True)
    new_dir = os.path.join(cwd,folder_name)
    col_name = i
    file_path = os.path.join(new_dir,f"{i}.csv")
    print(file_path)
# Out:
# /Users/pranay/Naresh IT/Python/EDA/freq_table_1/case_id.csv
# /Users/pranay/Naresh IT/Python/EDA/freq_table_1/continent.csv
# /Users/pranay/Naresh IT/Python/EDA/freq_table_1/education_of_employee.csv
# /Users/pranay/Naresh IT/Python/EDA/freq_table_1/has_job_experience.csv
# /Users/pranay/Naresh IT/Python/EDA/freq_table_1/requires_job_training.csv
# /Users/pranay/Naresh IT/Python/EDA/freq_table_1/region_of_employment.csv
# /Users/pranay/Naresh IT/Python/EDA/freq_table_1/unit_of_wage.csv
# /Users/pranay/Naresh IT/Python/EDA/freq_table_1/full_time_position.csv
# /Users/pranay/Naresh IT/Python/EDA/freq_table_1/case_status.csv

# %%
for i in cat[1:]:
    keys = visa[i].value_counts().keys()
    values = visa[i].value_counts().values
    d = pd.DataFrame(zip(keys,values),columns=['Lables','No of Applicants'])
    print(d)
# Out:
#           Lables  No of Applicants
# 0           Asia             16861
# 1         Europe              3732
# 2  North America              3292
# 3  South America               852
# 4         Africa               551
# 5        Oceania               192
#         Lables  No of Applicants
# 0   Bachelor's             10234
# 1     Master's              9634
# 2  High School              3420
# 3    Doctorate              2192
#   Lables  No of Applicants
# 0      Y             14802
# 1      N             10678
#   Lables  No of Applicants
# 0      N             22525
# 1      Y              2955
#       Lables  No of Applicants
# 0  Northeast              7195
# 1      South              7017
# 2       West              6586
# 3    Midwest              4307
# 4     Island               375
#   Lables  No of Applicants
# 0   Year             22962
# 1   Hour              2157
# 2   Week               272
# 3  Month                89
#   Lables  No of Applicants
# ...

# %%
keys = visa['education_of_employee'].value_counts().keys()
values = visa['education_of_employee'].value_counts().values
d = pd.DataFrame(zip(keys,values),columns=['Lables','No of Applicants'])
d
# Out:
#         Lables  No of Applicants
# 0   Bachelor's             10234
# 1     Master's              9634
# 2  High School              3420
# 3    Doctorate              2192

# %%
os.getcwd()
# Out:
# '/Users/pranay/Naresh IT/Python/EDA'

# %%
for i in cat[1:]:
    keys = visa[i].value_counts().keys()
    values = visa[i].value_counts().values
    d = pd.DataFrame(zip(keys,values),columns=['Lables','No of Applicants'])

    cwd = os.getcwd()
    folder_name = 'freq'
    os.makedirs(folder_name,exist_ok=True)
    new_dir = os.path.join(cwd,folder_name)
    path = os.path.join(new_dir,f"{i}.csv")
    
    d.to_csv(path,index=False)

# %%
visa.groupby('education_of_employee').size()
# Out:
# education_of_employee
# Bachelor's     10234
# Doctorate       2192
# High School     3420
# Master's        9634
# dtype: int64
