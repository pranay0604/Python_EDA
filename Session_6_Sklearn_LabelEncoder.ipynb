# %% [markdown]
# ### Feature Engineering
#
# - So far we have performed feature analysis
#
#     - Data frame quick checks
#
#     - categorical column analysis
#
#     - bar charts, pie charts
#
#     - numerical column analysis
#
#     - histograms, box plots, outliers
#
#     - bi-multi variate analysis
#
#     - correlation, covariance, etc
#
# - Now we need to learn Feature Engineering
#
#     - we will create a new columns for better ML models
#
#     - we will perform the **Encoding** which is to convert categorical to numerical data
#
#     - we will do data **transformations**
#
#     - we will perform **Scaling : Standardization and Normalization**
#
#     - we will perform the **missing value analysis**
#
# - Simply feature engineering means our data will be modified
#
# #### Encoding
#
# - Encoding means convert categorical data to Numerical data
#
# - ML/DL or any models works based on maths
#
# - Models can not understand english characters
#
# - So it is very important convert categorical label to numerical values
#
# - For example Gender column has two lables
#
#     - Male
#
#     - Female
#
# - Then Female represent as 0, Male represent as 1 based on alphabetical order

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

visa = pd.read_csv('/Users/pranay/Naresh IT/Data Files/Visadataset.csv')

cat = visa.select_dtypes(include='object').columns
num = visa.select_dtypes(exclude='object').columns

# %%
visa.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa['case_status']
# Out:
# 0           Denied
# 1        Certified
# 2           Denied
# 3           Denied
# 4        Certified
#            ...
# 25475    Certified
# 25476    Certified
# 25477    Certified
# 25478    Certified
# 25479    Certified
# Name: case_status, Length: 25480, dtype: object

# %%
visa['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
# number of labels are two
# 0 & 1
# 0 for Certified
# 1 for Denied
# map ==== dict

# %%
d = {'Certified':0,"Denied":1}

# %%
visa['case_status'].map(d)
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int64

# %%
visa['case_status'] = visa['case_status'].map(d)

# %%
visa['case_status']
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int64

# %%
visa['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
c = {'Asia':0,'Africa':1,'North America':2,'Europe':3,'South America':4,'Oceania':5}
visa['continent'] = visa['continent'].map(c)
visa['continent']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: continent, Length: 25480, dtype: int64

# %%
# n = visa['continent'].nunique()
# labels = visa['continent'].unique()
# dict_con = {labels[i] : i for i in range(len(labels)) }
# visa['continent'] = visa['continent'].map(dict_con)

# %%
# labels = visa['continent'].unique()
# d = {}
# for i in range(len(labels)):
#     d[labels[i]]=i
# d

# %%
visa = pd.read_csv('/Users/pranay/Naresh IT/Data Files/Visadataset.csv')
cat = visa.select_dtypes(include='object').columns
num = visa.select_dtypes(exclude='object').columns

for col in cat:
    n = visa[col].nunique()
    labels = visa[col].unique()
    dict_con = {labels[i] : i for i in range(len(labels)) }
    visa[col] = visa[col].map(dict_con)

visa
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          0                      0                   0
# 1            1          0                      1                   1
# 2            2          0                      2                   0
# 3            3          0                      2                   0
# 4            4          1                      1                   1
# ...        ...        ...                    ...                 ...
# 25475    25475          0                      2                   1
# 25476    25476          0                      0                   1
# 25477    25477          0                      1                   1
# 25478    25478          0                      1                   1
# 25479    25479          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %%
visa = pd.read_csv('/Users/pranay/Naresh IT/Data Files/Visadataset.csv')
cat = visa.select_dtypes(include='object').columns
num = visa.select_dtypes(exclude='object').columns

for col in cat[1:]:
    n = visa[col].nunique()
    labels = visa[col].unique()
    dict_con = {labels[i] : i for i in range(len(labels)) }
    visa[col] = visa[col].map(dict_con)

visa
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          0                      0                   0
# 1         EZYV02          0                      1                   1
# 2         EZYV03          0                      2                   0
# 3         EZYV04          0                      2                   0
# 4         EZYV05          1                      1                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          0                      2                   1
# 25476  EZYV25477          0                      0                   1
# 25477  EZYV25478          0                      1                   1
# 25478  EZYV25479          0                      1                   1
# 25479  EZYV25480          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

visa = pd.read_csv('/Users/pranay/Naresh IT/Data Files/Visadataset.csv')

cat = visa.select_dtypes(include='object').columns
num = visa.select_dtypes(exclude='object').columns

# %%
# visa = pd.read_csv('/Users/pranay/Naresh IT/Data Files/Visadataset.csv')
# cat = visa.select_dtypes(include='object').columns
# num = visa.select_dtypes(exclude='object').columns

# for col in cat[1:]:
#     n = visa[col].nunique()
#     labels = visa[col].unique()
#     dict_con = {labels[i] : i for i in range(len(labels)) }
#     visa[col] = visa[col].map(dict_con)

# visa

# %% [markdown]
# - we have encoded categorical data to numerical data using scratch
#
# - but the same way we have a **Package**
#
# - Name of Package is : **scikit-learn** aka sklearn
#
# - it is a heart of ML
#
# - 99% of all ML are under Sklearn package
#
# - Package : sklearn
#
#     - Module name : preprocessing
#
#         - Class : LabelEncoder
#
#             - Method :
#
#                       - fit
#                       - transform
#                       - fit_transform
#
# - while doing the  encoding
#
#     - we created the dictionary
#
#     - we use the dictionary on original data, the data become Encoded
#
#     - The **Data Changed**
#
# - **Create** and **Modify**
#
# - **Create** means : **fit** and **Modify** means : **transform**

# %%
from sklearn.preprocessing import LabelEncoder

# from sklearn.<module> import <class>

# %%
import sklearn

dir(sklearn)
# Out:
# ['_BUILT_WITH_MESON',
#  '__SKLEARN_SETUP__',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__check_build',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
#  '_distributor_init',
#  'base',
#  'clone',
#  'config_context',
#  'exceptions',
#  'externals',
#  'get_config',
#  'logger',
#  'logging',
#  'os',
#  'preprocessing',
#  'random',
#  'set_config',
#  'setup_module',
#  'show_versions',
#  'sklearn',
#  'sys',
#  'utils']

# %%
import sklearn

dir(sklearn)

from sklearn import preprocessing 

dir(preprocessing)

from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

visa['case_status'] = le.fit_transform(visa['case_status'])

# %%
visa['case_status']
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int64

# %%
visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from sklearn.preprocessing import LabelEncoder

visa = pd.read_csv('/Users/pranay/Naresh IT/Data Files/Visadataset.csv')

cat = visa.select_dtypes(include='object').columns
num = visa.select_dtypes(exclude='object').columns

le = LabelEncoder() 

for i in cat[1:]:
    
    visa[i] = le.fit_transform(visa[i])

visa
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
le.inverse_transform(visa['case_status'])
# Out:
# array(['Denied', 'Certified', 'Denied', ..., 'Certified', 'Certified',
#        'Certified'], dtype=object)

# %%
visa
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
le.fit_transform(visa['continent'])[:10]
# Out:
# array([1, 1, 1, 1, 0, 1, 1, 3, 1, 2])

# %%
visa['continent'].values
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
d = le.fit_transform(visa['continent'])

le.inverse_transform(d)
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %% [markdown]
# OneHotEncoder
# ------
#
# - one hot encoder means at a time one will be **ON**, another will be **OFF**
#
# - First how many labels are there in a column
#
# - That many new columns will be created extra
#
# - For example case status has two labels
#
#     - Certified
#
#     - Denied
#
# - So It will create Two new extra columns
#
#     - case_status_Certified
#
#     - case_status_Denied
#
# - At a time one column value become 1 other column value become 0
#
# - This means a **one hot encoder**
#
# |case_status|case_status_Certified|case_status_Denied|
# |-|-|-|
# |Certified|1|0|
# |Denied|0|1|
# |Denied|0|1|
# |Certified|1|0|

# %%
visa.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
# understand the patterns between input and output columns

we do not want relation between two inputs
        |
the two columns should be independent 
        |
perpendicular
        |
90 degrees Phase shift
        |
cos and sin 90
        |
cos 90 = sin 0
sin 0 = cos 90
        |
orthogonality

1 ==== 0


Curse of Dimensionality :- more labels -> more dimensions -> more process the data -> more time and more money 

Relationships :- 

- x1 with x1 -> auto correlation

- x1 with x2 -> multi collinearity

- x1 with y -> correlation
